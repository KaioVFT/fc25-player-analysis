# %%
# Import the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv("/Users/kaiov/Desktop/UFPB-CDN/csv/male_players.csv")

# Display the first 10 rows of the data(test)

df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  Rank                  Name  OVR  PAC  SHO  PAS  \
# 0             0           0     1         Kylian Mbappé   91   97   90   80
# 1             1           1     2                 Rodri   91   66   80   86
# 2             2           2     4        Erling Haaland   91   88   92   70
# 3             3           3     5       Jude Bellingham   90   80   87   83
# 4             4           4     7              Vini Jr.   90   95   84   81
# 5             5           5     9       Kevin De Bruyne   90   67   87   94
# 6             6           6    11            Harry Kane   90   65   93   84
# 7             7           7    12       Martin Ødegaard   89   70   82   89
# 8             8           8    13  Gianluigi Donnarumma   89   90   84   73
# 9             9           9    15               Alisson   89   86   85   85
#
#    DRI  DEF  ...   Nation              League               Team  \
# 0   92   36  ...   France    LALIGA EA SPORTS        Real Madrid
# ...

# %%
# Information about the data columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16161 entries, 0 to 16160
# Data columns (total 58 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           16161 non-null  int64
#  1   Unnamed: 0             16161 non-null  int64
#  2   Rank                   16161 non-null  int64
#  3   Name                   16161 non-null  object
#  4   OVR                    16161 non-null  int64
#  5   PAC                    16161 non-null  int64
#  6   SHO                    16161 non-null  int64
#  7   PAS                    16161 non-null  int64
#  8   DRI                    16161 non-null  int64
#  9   DEF                    16161 non-null  int64
#  10  PHY                    16161 non-null  int64
#  11  Acceleration           16161 non-null  int64
#  12  Sprint Speed           16161 non-null  int64
#  13  Positioning            16161 non-null  int64
#  14  Finishing              16161 non-null  int64
# ...

# %%
# Check columns

print(df.columns)
# Out:
# Index(['Rank', 'Name', 'OVR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY',
#        'Acceleration', 'Sprint Speed', 'Positioning', 'Finishing',
#        'Shot Power', 'Long Shots', 'Volleys', 'Penalties', 'Vision',
#        'Crossing', 'Free Kick Accuracy', 'Short Passing', 'Long Passing',
#        'Curve', 'Dribbling', 'Agility', 'Balance', 'Reactions', 'Ball Control',
#        'Composure', 'Interceptions', 'Heading Accuracy', 'Def Awareness',
#        'Standing Tackle', 'Sliding Tackle', 'Jumping', 'Stamina', 'Strength',
#        'Aggression', 'Position', 'Weak foot', 'Skill moves', 'Preferred foot',
#        'Height', 'Weight', 'Alternative positions', 'Age', 'Nation', 'League',
#        'Team', 'play style', 'url', 'GK Diving', 'GK Handling', 'GK Kicking',
#        'GK Positioning', 'GK Reflexes'],
#       dtype='object')

# %%
# Check for missing values

df.isnull().sum()   # No missing values
# Out:
# Unnamed: 0.1                 0
# Unnamed: 0                   0
# Rank                         0
# Name                         0
# OVR                          0
# PAC                          0
# SHO                          0
# PAS                          0
# DRI                          0
# DEF                          0
# PHY                          0
# Acceleration                 0
# Sprint Speed                 0
# Positioning                  0
# Finishing                    0
# Shot Power                   0
# Long Shots                   0
# Volleys                      0
# Penalties                    0
# Vision                       0
# Crossing                     0
# Free Kick Accuracy           0
# Short Passing                0
# Long Passing                 0
# Curve                        0
# Dribbling                    0
# Agility                      0
# Balance                      0
# Reactions                    0
# Ball Control                 0
# ...

# %%
# Check for duplicate values

df.duplicated().sum()   # No duplicate values
# Out:
# 0

# %%
# Calculate the 10 players with the highest overall average or 'OVR'

df_bestOVR = df.sort_values(by='OVR', ascending=False)
df_bestOVR.head(10)
# Out:
#     Rank                   Name  OVR  PAC  SHO  PAS  DRI  DEF  PHY  \
# 0      1          Kylian Mbappé   91   97   90   80   92   36   78
# 2      4         Erling Haaland   91   88   92   70   81   45   88
# 1      2                  Rodri   91   66   80   86   84   87   85
# 3      5        Jude Bellingham   90   80   87   83   88   78   83
# 4      7               Vini Jr.   90   95   84   81   91   29   69
# 5      9        Kevin De Bruyne   90   67   87   94   87   65   78
# 6     11             Harry Kane   90   65   93   84   83   49   82
# 11    18       Lautaro Martínez   89   82   88   75   87   54   85
# 14    22          Mohamed Salah   89   89   87   82   88   45   75
# 13    21  Marc-André ter Stegen   89   86   85   89   91   47   86
#
#     Acceleration  ...     Nation            League               Team  \
# 0             97  ...     France  LALIGA EA SPORTS        Real Madrid
# 2             80  ...     Norway    Premier League    Manchester City
# ...

# %%
# Calculate the 10 players with the lowest overall average or 'OVR'

df_worstOVR = df.sort_values(by='OVR', ascending=False)
df_worstOVR.tail(10)
# Out:
#         Rank                    Name  OVR  PAC  SHO  PAS  DRI  DEF  PHY  \
# 16149  17717             Kim Se Hoon   47   63   36   47   48   37   42
# 16148  17717          Kim Myeong Jun   47   49   46   38   46   20   51
# 16147  17717            Kim Dong Min   47   52   34   43   49   45   43
# 16146  17717           Kang Gyo Hoon   47   53   35   45   46   43   54
# 16145  17717            Isaiah Jones   47   75   31   43   49   49   49
# 16144  17717              Jo In Jung   47   65   37   46   47   42   59
# 16142  17717  Lalchungnunga Chhangte   47   66   37   45   48   43   53
# 16141  17717   Fredy Chawngthansanga   47   62   40   45   49   32   46
# 16140  17717          Mohammed Aimen   47   64   45   45   53   26   49
# 16160  17717               Wu Yuhang   47   56   34   43   45   43   54
#
#        Acceleration  ...          Nation      League              Team  \
# 16149            64  ...  Korea Republic  K League 1    Incheon United
# ...

# %%
# Calculate the 20 players with the highest estimated potential or 'Potential' under 20 years old

# Filtrar jogadores com idade menor que 20 anos
df_under_20 = df[df["Age"] <= 20]

# Criar a coluna de Potencial Estimado
df_under_20["Potential_Estimate"] = df_under_20["OVR"] + (25 - df_under_20["Age"]) * 0.5

# Garante que o potencial mínimo seja o OVR atual (evita valores menores)
df_under_20["Potential_Estimate"] = df_under_20[["OVR", "Potential_Estimate"]].max(axis=1)

# Ordenar os jogadores com maior potencial estimado
top_potential = df_under_20.sort_values(by="Potential_Estimate", ascending=False)

# Exibir os 20 jogadores com maior potencial estimado
print(top_potential[["Name", "Age", "OVR", "Potential_Estimate"]].head(20))
# Out:
#                     Name  Age  OVR  Potential_Estimate
# 167                 Gavi   20   83                85.5
# 349         Lamine Yamal   17   81                85.0
# 253              Savinho   20   82                84.5
# 285                Balde   20   81                83.5
# 457   Warren Zaïre-Emery   18   80                83.5
# 523           João Neves   19   79                82.0
# 517   Alejandro Garnacho   20   79                81.5
# 603        António Silva   20   79                81.5
# 802            Leny Yoro   18   78                81.5
# 695           Arda Güler   19   78                81.0
# 766     Guillaume Restes   19   78                81.0
# 665     Ousmane Diomande   20   78                80.5
# 776     Giorgio Scalvini   20   78                80.5
# 799         Adam Wharton   20   78                80.5
# 956              Endrick   18   77                80.5
# 1021          Mathys Tel   19   77                80.0
# ...

# %%
# Calculate the 20 players with the highest estimated potential regardless of age

# Criar a coluna de Potencial Estimado
df["Potential_Estimate"] = df["OVR"] + (25 - df["Age"]) * 0.5

# Garante que o potencial mínimo seja o OVR atual (evita valores menores)
df["Potential_Estimate"] = df[["OVR", "Potential_Estimate"]].max(axis=1)

# Ordenar os jogadores com maior potencial estimado
top_potential = df.sort_values(by="Potential_Estimate", ascending=False)

# Exibir os 20 jogadores com maior potencial estimado
print(top_potential[["Name", "Age", "OVR", "Potential_Estimate"]].head(20))
# Out:
#                      Name  Age  OVR  Potential_Estimate
# 3         Jude Bellingham   21   90                92.0
# 2          Erling Haaland   24   91                91.5
# 0           Kylian Mbappé   25   91                91.0
# 1                   Rodri   28   91                91.0
# 4                Vini Jr.   24   90                90.5
# 6              Harry Kane   31   90                90.0
# 25          Florian Wirtz   21   88                90.0
# 5         Kevin De Bruyne   33   90                90.0
# 7         Martin Ødegaard   25   89                89.0
# 8    Gianluigi Donnarumma   25   89                89.0
# 9                 Alisson   31   89                89.0
# 10       Thibaut Courtois   32   89                89.0
# 12        Virgil van Dijk   33   89                89.0
# 13  Marc-André ter Stegen   32   89                89.0
# 14          Mohamed Salah   32   89                89.0
# 29          Jamal Musiala   21   87                89.0
# ...

# %%
# Best players by position - GK
df_bestGK = df.loc[df['Position'] == 'GK'].sort_values(by='OVR', ascending=False)
df_bestGK.head(20)
# Out:
#      Rank                   Name  OVR  PAC  SHO  PAS  DRI  DEF  PHY  \
# 8      13   Gianluigi Donnarumma   89   90   84   73   90   52   87
# 10     16       Thibaut Courtois   89   85   89   76   90   46   88
# 13     21  Marc-André ter Stegen   89   86   85   89   91   47   86
# 9      15                Alisson   89   86   85   85   89   56   90
# 21     33                Ederson   88   87   82   91   87   64   86
# 23     38              Jan Oblak   88   85   90   78   87   46   86
# 26     43           Gregor Kobel   88   87   86   73   89   44   87
# 36     56           Mike Maignan   87   84   83   85   88   64   84
# 42     65      Emiliano Martínez   87   84   82   83   86   56   87
# 44     67            Yann Sommer   87   83   84   85   89   50   86
# 62     94             Unai Simón   86   85   81   78   86   49   85
# 63     97           Manuel Neuer   86   83   81   90   83   49   88
# 77    101   Giorgi Mamardashvili   85   86   83   72   85   48   85
# ...

# %%
# Best players by position - RW
df_bestCB = df.loc[df['Position'] == 'CB'].sort_values(by='OVR', ascending=False)
df_bestCB.head(20)
# Out:
#      Rank                Name  OVR  PAC  SHO  PAS  DRI  DEF  PHY  \
# 12     20     Virgil van Dijk   89   78   60   71   71   89   86
# 24     40     Antonio Rüdiger   88   82   55   73   70   86   86
# 18     29          Rúben Dias   88   67   39   70   69   89   87
# 27     44      William Saliba   87   82   39   70   74   87   83
# 39     61          Marquinhos   87   79   56   75   74   89   81
# 40     62  Alessandro Bastoni   87   75   43   75   76   87   83
# 46     69             Gabriel   86   69   41   63   61   86   82
# 58     89        Jonathan Tah   86   71   38   60   62   86   84
# 60     91              Bremer   86   82   50   58   66   86   85
# 85    101  Nico Schlotterbeck   85   77   59   70   73   85   82
# 86    101         John Stones   85   69   58   75   79   85   77
# 65    101         David Alaba   85   79   71   83   80   85   77
# 68    101        Éder Militão   85   85   50   69   71   85   82
# ...
